# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# "parse_dates" converte o campo para o tipo data
# "dayfirst=True" Em uma data indica no campo de data que o primeiro bloco é de dia 

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Digital Innovation One/13 - Fundamentos de ETL com Python/ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)

df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %% [markdown]
# **Linha/Indice 1, Coluna 'ocorrencia_cidade'**

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %% [markdown]
# **Linha/Indice 1 até 3 **

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia2  ... total_recomendacoes
# 1               40349  ...                   0
# 2               40351  ...                   0
# 3               39527  ...                   0
#
# [3 rows x 8 columns]

# %% [markdown]
# **Linha/Indice 1 e 40**

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia2  ... total_recomendacoes
# 10               39789  ...                   0
# 40               39158  ...                   0
#
# [2 rows x 8 columns]

# %% [markdown]
# **Todas linhas de uma coluna**

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %% [markdown]
# **Verifica se a coluna tem valores únicos**

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# **Torna a coluna com indice**

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2  ... total_recomendacoes
# 0               40211  ...                   0
# 1               40349  ...                   0
# 2               40351  ...                   0
# 3               39527  ...                   0
# 4               40324  ...                   0
#
# [5 rows x 8 columns]

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %% [markdown]
# **Remove o indice criado e retorna ao antigo**

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2  ... total_recomendacoes
# 0               40211  ...                   0
# 1               40349  ...                   0
# 2               40351  ...                   0
# 3               39527  ...                   0
# 4               40324  ...                   0
#
# [5 rows x 8 columns]

# %% [markdown]
# **Na linha de index 0, coluna 'ocorrencia_aerodromo' atribui o valor vazio no lugar**

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2  ... total_recomendacoes
# 0               40211  ...                   0
#
# [1 rows x 8 columns]

# %% [markdown]
# **Coloca o valor 20 em todos campos da linha de index 1**

# %%
df.loc[1] = 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
# 1                  20                       20                20
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
#
#    total_recomendacoes
# 0                    0
# 1                   20

# %% [markdown]
# **Coloca o valor 10 para todas linhas da coluna 'total_Recomendacoes'**

# %%
df.loc[:,'total_recomendacoes'] = 10

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                INCIDENTE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# **Cria uma coluna do dataframe baseada em outra**

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                INCIDENTE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# **Quando a coluna ocorrencia_uf == SP, altera a coluna ocorrecia_classificacao para grave**

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    GRAVE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %% [markdown]
# **Filtra o dataframe por apenas ocorrencia_uf == SP**

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 11                 40069                    GRAVE         SÃO PAULO
# 16                 39809                    GRAVE         SÃO PAULO
# 18                 39828                    GRAVE            SANTOS
# 26                 39847                    GRAVE          SOROCABA
# 27                 39768                    GRAVE          CAMPINAS
# ...                  ...                      ...               ...
# 5704               79739                    GRAVE         SÃO PAULO
# 5705               79705                    GRAVE          SOROCABA
# 5715               79718                    GRAVE         SÃO PAULO
# 5742               79800                    GRAVE         SÃO PAULO
# 5747               79804                    GRAVE          CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    GRAVE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 ****  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# ...

# %% [markdown]
# **Substitui valores da coluna que tem * por valor NA**

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1                  20                       20                  20
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            20                   20                   20              20
# 2            RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3            MT                 <NA>  2010-01-04 00:00:00        17:30:00
# 4            RS                 SBPK  2010-01-05 00:00:00        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                   10                RJ
# ...

# %% [markdown]
# **Substitui todos esses valores por NA**

# %%
df.replace(['**','###!','####','****','NULL'], pd.NA, inplace=True)

# %% [markdown]
# **Verifica os valores NA existentes**

# %%
df.isnull().sum() # Ou df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2198
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# **Atribui um valor para todos valores que forem NA**

# %%
df.fillna(1000, inplace=True)
# Out:
#       codigo_ocorrencia2  ... total_recomendacoes
# 0                  40211  ...                   0
# 1                  40349  ...                   0
# 2                  40351  ...                   0
# 3                  39527  ...                   0
# 4                  40324  ...                   0
# ...                  ...  ...                 ...
# 5747               79804  ...                   0
# 5748               79757  ...                   0
# 5749               79802  ...                   0
# 5750               79756  ...                   0
# 5751               79844  ...                   0
#
# [5752 rows x 8 columns]

# %% [markdown]
# **Atribui um valor apenas para uma coluna especifica que tenha NA**

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %% [markdown]
# **Cria coluna**

# %%
df['total_recomendacoes_bkp'] = df.	total_recomendacoes

# %% [markdown]
# **Exclui Coluna**

# %%
df.drop('total_recomendacoes_bkp', axis=1, inplace=True)

# %% [markdown]
# **Exclui todos valores NA de uma coluna**

# %%
df.dropna(subset=['ocorrencia_uf'], inplace=True)

# %% [markdown]
# **Exclui Duplicados**

# %%
df.drop_duplicates(inplace=True)
